# %% [markdown]
# <a href="https://colab.research.google.com/github/seo-minsu/Python_Programming_Study/blob/main/Exercise_minsu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?
# 어떤 대륙이 맥주를 평균보다 많이 마시는지?
#
# 1. 대륙으로 'groupby'
# 2. beer serving의 평균

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column
# 대륙별 모든 알코올 소비량

# %%
## 해결 안됨 : drinks.select_dtypes(include='number')
drinks.groupby('continent').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1873         try:
# -> 1874             res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     848
# --> 849         result = self._aggregate_series_pure_python(obj, func)
#     850
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     876         for i, group in enumerate(splitter):
# --> 877             res = func(group)
#     878             res = extract_result(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
# ...

# %%
## drinks.groupby('continent')['beer_servings',	'spirit_servings',	'wine_servings',	'total_litres_of_pure_alcohol'].mean()
해당 오류는 Pandas에서 비추천된 방식으로 열을 선택하려 했기 때문입니다. Pandas에서는 여러 열을 선택할 때 리스트 인덱싱을 사용하도록 변경되었습니다.
# Out:
#   File "<ipython-input-61-37fbf7cdc12f>", line 2
#     해당 오류는 Pandas에서 비추천된 방식으로 열을 선택하려 했기 때문입니다. Pandas에서는 여러 열을 선택할 때 리스트 인덱싱을 사용하도록 변경되었습니다.
#        ^
# SyntaxError: invalid syntax

# %%
drinks.groupby('continent')[['beer_servings',	'spirit_servings',	'wine_servings',	'total_litres_of_pure_alcohol']].mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent')[['beer_servings',	'spirit_servings',	'wine_servings',	'total_litres_of_pure_alcohol']].median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# \### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent').spirit_servings.describe()
# Out:
#            count        mean        std   min    25%    50%     75%    max
# continent
# AF          53.0   16.339623  28.102794   0.0   1.00    3.0   19.00  152.0
# AS          44.0   60.840909  84.362160   0.0   1.00   16.0   98.00  326.0
# EU          45.0  132.555556  77.589115   0.0  81.00  122.0  173.00  373.0
# OC          16.0   58.437500  70.504817   0.0  18.00   37.0   65.25  254.0
# SA          12.0  114.750000  77.077440  25.0  65.75  108.5  148.75  302.0

# %%
## 지선생 describe() 메서드는 기본적으로 count, mean, std, min, 25%, 50%, 75%, max와 같은 다양한 통계치를 제공합니다.
##만약 min, max, mean만 출력하고 싶다면, 다음과 같이 코드를 수정할 수 있습니다

##방법 1. agg 함수
drinks.groupby('continent')['spirit_servings'].agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
##방법 2. describe() 메서드 사용 후 필요한 열만 선택
spirit_stats = drinks.groupby('continent')['spirit_servings'].describe()
selected_stats = spirit_stats[['mean', 'min', 'max']]
## 한줄로 할 수 있는 방법?
